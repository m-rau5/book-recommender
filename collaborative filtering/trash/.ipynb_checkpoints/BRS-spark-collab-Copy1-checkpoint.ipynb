# %% [markdown]
# # Setup

# %%
from pyspark.sql import SparkSession 
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS, ALSModel
from pyspark.ml.tuning import TrainValidationSplit,CrossValidator, ParamGridBuilder
from pyspark.sql.functions import col, explode, when

# %% [markdown]
# __Pyspark setup__

# %%
import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
spark = SparkSession.builder \
    .master('local') \
    .appName('BRS-pyspark') \
    .config("spark.driver.memory", "12g") \
    .config("spark.driver.extraJavaOptions", "-Xss8M") \
    .getOrCreate()

spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://RaulPC:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>BRS-pyspark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ---

# %% [markdown]
# # Loading the datasets

# %%
books_df = spark.read.csv("../datasets/clean/filtered_datasets/final_books_collab.csv",header=True,inferSchema=True)
book_ratings = spark.read.csv("../datasets/clean/filtered_datasets/final_ratings_collab.csv",header=True,inferSchema=True)

# %%
book_ratings.show(2)
# Out:
# +-------+-----------+-------+
# |User-ID|Book-Rating|Book-Id|
# +-------+-----------+-------+
# | 277427|          9|      9|
# | 277427|          9|    287|
# +-------+-----------+-------+
# only showing top 2 rows

# %%
(training, test) = book_ratings.randomSplit([0.8,0.2], seed=42)

# %% [markdown]
# ## Setting up evaluator, model and paramaters

# %%
# Evaluator = RMSE -> sqroot of the avg squared differences between 
#                                   predicted and observed outcomes
evaluator = RegressionEvaluator(metricName="rmse", labelCol="Book-Rating",
                                predictionCol="prediction")

# %%
als = ALS(userCol="User-ID",itemCol="Book-Id", ratingCol="Book-Rating",
                coldStartStrategy="drop",nonnegative=True)

# %%
# param_grid -> for fine-tuning of the model -> hyperparams
param_grid = ParamGridBuilder()\
             .addGrid(als.rank,[70])\
             .addGrid(als.maxIter,[140])\
             .addGrid(als.regParam, [0.9])\
             .build()
# hyperparam "rank" - rank of U and P 
# hyperparam "maxIter" - how many times to alternate
# hyperparam "regParam" - regularization param to prevent overfitting

# %% [markdown]
# We use cross validator to create multiple models and choose best one

# %%
cv = CrossValidator(estimator=als,
                    estimatorParamMaps=param_grid,
                    evaluator=evaluator,
                    numFolds=3)

# %% [markdown]
# Train the models

# %%
model = cv.fit(training)
bestModel = model.bestModel

# %% [markdown]
# ---

# %% [markdown]
# # Testing the model

# %% [markdown]
# Now we see how the model performs on our test dataset we created

# %%
pred = bestModel.transform(test)
rmse = evaluator.evaluate(pred)
rmse
# Out:
# 2.106743837231433

# %%
print("rank :",bestModel.rank," maxiter :",bestModel._java_obj.parent().getMaxIter(), " regparam :",bestModel._java_obj.parent().getRegParam())
# Out:
# rank : 70  maxiter : 140  regparam : 0.9

# %% [markdown]
# ### Function to get user recommendations from the model

# %%
def recommendBooks(user_id, model, book_df):
    user_recs = model.recommendForUserSubset(spark.createDataFrame([[user_id]], ["User-ID"]), numItems=10)
    
    # use "explode" on the array of recommendations to separate rows
    user_recs_exploded = user_recs.select(col("User-ID"), explode("recommendations").alias("recommendation"))
    
    # get recommended books and ratings + join on their name
    recommended_books = user_recs_exploded.select(col("User-ID"), col("recommendation.Book-Id").alias("Book-Id"), col("recommendation.rating").alias("Predicted-Rating"))
    recommended_books_with_names = recommended_books.join(book_df, on="Book-Id", how="inner")
    
    # Clip predicted ratings to the range [0, 10]
    recommended_books_with_names = recommended_books_with_names.withColumn("Predicted-Rating", when(col("Predicted-Rating") > 10, 10).otherwise(col("Predicted-Rating")))
    
    return recommended_books_with_names

# %% [markdown]
# #### __Code to plot user reviews for comparison__

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plotUserRatings(user_id, book_ratings, book_df):
    # filter book ratings for the user
    ratings = book_ratings.filter(book_ratings["User-ID"] == user_id)
    ratings_with_names = ratings.join(book_df, on="Book-Id", how="inner")
    
    book_names = ratings_with_names.select("Book-Title").collect()
    ratings = ratings_with_names.select("Book-Rating").collect()
    
    # make the spark dataframe into a pandas df for plotting
    df = pd.DataFrame({"Book Title": [row["Book-Title"] for row in book_names],
                       "Rating": [row["Book-Rating"] for row in ratings]})

    # --- plotting code ---
    plt.figure(figsize=(10, 6))
    plt.barh(df["Book Title"], df["Rating"], color="skyblue")
    plt.xlabel("Rating")
    plt.ylabel("Book Title")
    plt.title(f"Books Rated by User {user_id}")
    plt.gca().invert_yaxis()
    plt.show()

# %% [markdown]
# #### Apllying the model for some existing users

# %%
recommended_books = recommendBooks(4017, bestModel, books_df).toPandas() # we use to pandas to get a cleaner output
recommended_books.head(5)
# Out:
#    Book-Id  User-ID  Predicted-Rating        ISBN  \
# 0      356     4017              10.0  0140444300
# 1     2400     4017              10.0  0811201120
# 2     2371     4017              10.0  0743482778
# 3      354     4017              10.0  0679727299
# 4     1435     4017              10.0  0142000655
#
#                                           Book-Title          Book-Author  \
# 0                  Les Miserables (Penguin Classics)          Victor Hugo
# 1  Henry Miller on Writing (New Directions Paperb...         Henry Miller
# 2         Twelfth Night (Folger Shakespeare Library)  William Shakespeare
# 3                               The Annotated Lolita     Vladimir Nabokov
# 4                                       East of Eden       John Steinbeck
#
#                                Publisher  Year-Of-Publication  \
# 0                          Penguin Books                 1982
# 1  New Directions Publishing Corporation                 1964
# 2                Washington Square Press                 2004
# 3                      Vintage Books USA                 1991
# 4                          Penguin Books                 2002
#
#            categories                                        description  \
# 0             Fiction  After nineteen years in prison, Jean Valjean h...
# 1  Literary Criticism  Some of the most rewarding pages in Henry Mill...
# 2               Drama  Background information about Shakespeare, Eliz...
# 3             Fiction  The textural discussion accompanying this nove...
# 4             Fiction  The biblical account of Cain and Abel is echoe...
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0811201120.0...
# 2  http://images.amazon.com/images/P/0743482778.0...
# 3  http://images.amazon.com/images/P/0679727299.0...
# 4  http://images.amazon.com/images/P/0142000655.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0811201120.0...
# 2  http://images.amazon.com/images/P/0743482778.0...
# 3  http://images.amazon.com/images/P/0679727299.0...
# 4  http://images.amazon.com/images/P/0142000655.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0811201120.0...
# 2  http://images.amazon.com/images/P/0743482778.0...
# 3  http://images.amazon.com/images/P/0679727299.0...
# 4  http://images.amazon.com/images/P/0142000655.0...

# %%
plotUserRatings(4017, book_ratings, books_df)

# %%
recommended_books = recommendBooks(6238, bestModel, books_df).toPandas() # to pandas to get a cleaner output
recommended_books.head(5)
# Out:
#    Book-Id  User-ID  Predicted-Rating        ISBN  \
# 0      356     6238          10.00000  0140444300
# 1      354     6238          10.00000  0679727299
# 2     2371     6238          10.00000  0743482778
# 3     1441     6238           9.98838  0517543052
# 4      246     6238           9.94011  0345455916
#
#                                          Book-Title             Book-Author  \
# 0                 Les Miserables (Penguin Classics)             Victor Hugo
# 1                              The Annotated Lolita        Vladimir Nabokov
# 2        Twelfth Night (Folger Shakespeare Library)     William Shakespeare
# 3                                       Be Here Now  Lama Foundation Editor
# 4  The Probable Future (Ballantine Reader's Circle)           ALICE HOFFMAN
#
#                  Publisher  Year-Of-Publication           categories  \
# 0            Penguin Books                 1982              Fiction
# 1        Vintage Books USA                 1991              Fiction
# 2  Washington Square Press                 2004                Drama
# 3  Three Rivers Press (CA)                 1971  Body, Mind & Spirit
# 4         Ballantine Books                 2004              Fiction
#
#                                          description  \
# 0  After nineteen years in prison, Jean Valjean h...
# 1  The textural discussion accompanying this nove...
# 2  Background information about Shakespeare, Eliz...
# 3  This book is enhanced with content such as aud...
# 4  Struggling to cope with her unwanted ability t...
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0679727299.0...
# 2  http://images.amazon.com/images/P/0743482778.0...
# 3  http://images.amazon.com/images/P/0517543052.0...
# 4  http://images.amazon.com/images/P/0345455916.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0679727299.0...
# 2  http://images.amazon.com/images/P/0743482778.0...
# 3  http://images.amazon.com/images/P/0517543052.0...
# 4  http://images.amazon.com/images/P/0345455916.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0679727299.0...
# 2  http://images.amazon.com/images/P/0743482778.0...
# 3  http://images.amazon.com/images/P/0517543052.0...
# 4  http://images.amazon.com/images/P/0345455916.0...

# %%
plotUserRatings(4017, book_ratings, books_df)

# %%
# bestModel.write().overwrite().save("./models/model_rmse_2.1677")

# %% [markdown]
# ---
