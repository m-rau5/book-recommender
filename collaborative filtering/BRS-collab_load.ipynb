# %% [markdown]
# # Setup

# %%
from pyspark.sql import SparkSession 
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS, ALSModel
from pyspark.ml.tuning import TrainValidationSplit,CrossValidator, ParamGridBuilder, CrossValidatorModel
from pyspark.sql.functions import col, explode, when

# %% [markdown]
# __Pyspark setup__

# %%
import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
spark = SparkSession.builder \
    .master('local') \
    .appName('BRS-pyspark') \
    .config("spark.driver.memory", "12g") \
    .config("spark.driver.extraJavaOptions", "-Xss12M") \
    .getOrCreate()

spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://RaulPC:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>BRS-pyspark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ---

# %% [markdown]
# # Loading the datasets

# %%
books_df = spark.read.csv("../datasets/clean/filtered_datasets/Final/final_books.csv",header=True,inferSchema=True)
book_ratings = spark.read.csv("../datasets/clean/filtered_datasets/Final/final_ratings.csv",header=True,inferSchema=True)

# %%
book_ratings.show(2)
# Out:
# +-------+-----------+-------+
# |User-ID|Book-Rating|Book-Id|
# +-------+-----------+-------+
# | 277427|          9|      9|
# | 277427|          9|    278|
# +-------+-----------+-------+
# only showing top 2 rows

# %%
mPath =  "./models/model_1_50_100_07"
persistedModel = CrossValidatorModel.load(mPath)

# predict
predictionsDF = persistedModel.transform(book_ratings)

# %%
predictionsDF.show()
# Out:
# +-------+-----------+-------+----------+
# |User-ID|Book-Rating|Book-Id|prediction|
# +-------+-----------+-------+----------+
# | 277427|          9|      9|  8.403077|
# | 277427|          9|    278|  8.473743|
# | 277427|         10|    202|  8.555579|
# | 277427|         10|    159| 7.5709944|
# | 277427|          9|     63|  8.107115|
# | 277427|         10|    481|  9.597159|
# | 278026|          9|   1122|  7.995034|
# | 278026|          8|    226| 7.3062773|
# | 278026|          8|   1203|  7.337729|
# | 278418|         10|    640|  8.299643|
# | 278418|          8|     36| 7.6102643|
# | 278418|          7|    692| 7.3070483|
# | 278582|          7|    292| 7.3428893|
# | 278582|          7|    260| 6.7946076|
# | 278582|         10|     52| 7.8803596|
# | 278633|          7|     27|  6.515313|
# | 278633|          7|    336|  5.915984|
# | 278633|          7|    428|  6.530921|
# |    254|          5|    494|  5.174255|
# |    254|          9|    205|  5.930076|
# +-------+-----------+-------+----------+
# only showing top 20 rows

# %%
model = persistedModel.bestModel

# %%
def scale_ratings(predictions):
    # Get the maximum and minimum predicted ratings
    max_rating = predictions.selectExpr("max(`Predicted-Rating`)").collect()[0][0]
    min_rating = 1

    # Scale the ratings to the range [0, 10]
    scaled_predictions = predictions.withColumn("Scaled-Rating", ((col("Predicted-Rating") - min_rating) / (max_rating - min_rating)) * 10)

    # Reorder the columns to place Scaled-Rating next to Predicted-Rating
    scaled_predictions = scaled_predictions.select(
        "User-ID", "Book-Id", "Predicted-Rating", "Scaled-Rating", 
        *[col for col in scaled_predictions.columns if col not in ["User-ID", "Book-Id", "Predicted-Rating", "Scaled-Rating"]]
    )
    
    return scaled_predictions

def recommendBooks(user_id, model, book_df):
    user_recs = model.recommendForUserSubset(spark.createDataFrame([[user_id]], ["User-ID"]), numItems=10)
    
    # Use "explode" on the array of recommendations to separate rows
    user_recs_exploded = user_recs.select(col("User-ID"), explode("recommendations").alias("recommendation"))
    
    # Get recommended books and ratings + join on their name
    recommended_books = user_recs_exploded.select(col("User-ID"), col("recommendation.Book-Id").alias("Book-Id"), col("recommendation.rating").alias("Predicted-Rating"))
    recommended_books_with_names = recommended_books.join(book_df, on="Book-Id", how="inner")

    # Scale the ratings to the range [0, 10]
    scaled_recommendations = scale_ratings(recommended_books_with_names)

    return scaled_recommendations

# %% [markdown]
# #### Apllying the model for some existing users

# %%
recommended_books = recommendBooks(4017, model, books_df).toPandas() # we use to pandas to get a cleaner output
recommended_books
# Out:
#    User-ID  Book-Id  Predicted-Rating  Scaled-Rating        ISBN  \
# 0     4017      346         11.900790      10.000000  0140444300
# 1     4017     1485         11.577393       9.703326  0802806414
# 2     4017     2308         11.209471       9.365808  0811201120
# 3     4017     1154         11.145123       9.306777  0618260587
# 4     4017     2280         10.777975       8.969969  0743482778
# 5     4017      661         10.687587       8.887050  0452011876
# 6     4017      540         10.559708       8.769738  0800871863
# 7     4017     1395         10.537687       8.749538  0517543052
# 8     4017      398         10.459037       8.677386  0156004801
# 9     4017      846         10.408650       8.631164  1560252480
#
#                                           Book-Title             Book-Author  \
# 0                  Les Miserables (Penguin Classics)             Victor Hugo
# 1  The Pilgrim's Regress: An Allegorical Apology ...             C. S. Lewis
# 2  Henry Miller on Writing (New Directions Paperb...            Henry Miller
# 3                              The Lord of the Rings        J. R. R. Tolkien
# 4         Twelfth Night (Folger Shakespeare Library)     William Shakespeare
# 5                                     Atlas Shrugged                Ayn Rand
# 6                                            Silence            Shusaku Endo
# 7                                        Be Here Now  Lama Foundation Editor
# 8                  All the King's Men (Harvest Book)      Robert Penn Warren
# 9                                Requiem for a Dream        Hubert Selby Jr.
#
#                                Publisher  Year-Of-Publication  \
# 0                          Penguin Books                 1982
# 1     Wm. B. Eerdmans Publishing Company                 1992
# 2  New Directions Publishing Corporation                 1964
# 3               Houghton Mifflin Company                 2002
# 4                Washington Square Press                 2004
# 5                            Plume Books                 1999
# 6                  Parkwest Publications                 1980
# 7                Three Rivers Press (CA)                 1971
# 8                          Harvest Books                 1996
# 9                  Thunder's Mouth Press                 2000
#
#             categories                                        description  \
# 0              Fiction  After nineteen years in prison, Jean Valjean h...
# 1             Religion  The first book written by C. S. Lewis after hi...
# 2   Literary Criticism  Some of the most rewarding pages in Henry Mill...
# 3              Fiction  An epic detailing the Great War of the Ring, a...
# 4                Drama  Background information about Shakespeare, Eliz...
# 5           Capitalism  The decisions of a few industrial leaders shak...
# 6              Fiction  Sustained by dreams of glorious martyrdom, a s...
# 7  Body, Mind & Spirit  This book is enhanced with content such as aud...
# 8              Fiction  Willie Stark's obsession with political power ...
# 9              Fiction  "The acclaimed novel that inspired the Darren ...
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0802806414.0...
# 2  http://images.amazon.com/images/P/0811201120.0...
# 3  http://images.amazon.com/images/P/0618260587.0...
# 4  http://images.amazon.com/images/P/0743482778.0...
# 5  http://images.amazon.com/images/P/0452011876.0...
# 6  http://images.amazon.com/images/P/0800871863.0...
# 7  http://images.amazon.com/images/P/0517543052.0...
# 8  http://images.amazon.com/images/P/0156004801.0...
# 9   Requiem for a Dream makes it to the big scree...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0802806414.0...
# 2  http://images.amazon.com/images/P/0811201120.0...
# 3  http://images.amazon.com/images/P/0618260587.0...
# 4  http://images.amazon.com/images/P/0743482778.0...
# 5  http://images.amazon.com/images/P/0452011876.0...
# 6  http://images.amazon.com/images/P/0800871863.0...
# 7  http://images.amazon.com/images/P/0517543052.0...
# 8  http://images.amazon.com/images/P/0156004801.0...
# 9                                  Jennifer Connelly
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0140444300.0...
# 1  http://images.amazon.com/images/P/0802806414.0...
# 2  http://images.amazon.com/images/P/0811201120.0...
# 3  http://images.amazon.com/images/P/0618260587.0...
# 4  http://images.amazon.com/images/P/0743482778.0...
# 5  http://images.amazon.com/images/P/0452011876.0...
# 6  http://images.amazon.com/images/P/0800871863.0...
# 7  http://images.amazon.com/images/P/0517543052.0...
# 8  http://images.amazon.com/images/P/0156004801.0...
# 9                                      Marlon Wayans
