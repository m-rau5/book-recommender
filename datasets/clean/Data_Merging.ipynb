# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
#
# # Setting up the dataframes

# %% [markdown]
# We are using two datasets:
# - __main_books_df__: a small dataset providing extra data for content based filtering book , eg. descriptions and geres;
# - __book_list_large_df__: a larger one providing a link to a ratings dataset used for the collaborative filtering part + images for the GUI.
#
# Methodology: We keep all entries from the smaller dataset that are present in the larger one. Like this, we can later modify the large reviews dataset to only contain reviews for the books we have already filtered here

# %%
#Main dataset with descriptions
main_books_df = pd.read_csv("source_datasets/abdallah_books_with_descriptions.csv")

#Large book dataset (over 270k entries)
book_list_large_df = pd.read_csv("source_datasets/book_dataset_large/books_large.csv",low_memory=False)

# %%
book_list_large_df.head(3)
# Out:
#          ISBN            Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448   Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018          Clara Callan  Richard Bruce Wright                2001
# 2  0060973129  Decision in Normandy          Carlo D'Este                1991
#
#                  Publisher  \
# 0  Oxford University Press
# 1    HarperFlamingo Canada
# 2          HarperPerennial
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg
# 1  http://images.amazon.com/images/P/0002005018.01.THUMBZZZ.jpg
# 2  http://images.amazon.com/images/P/0060973129.01.THUMBZZZ.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0060973129.01.MZZZZZZZ.jpg
#
#                                                     Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0060973129.01.LZZZZZZZ.jpg

# %%
main_books_df.head(3)
# Out:
#           isbn13      isbn10         title subtitle  \
# 0  9780002005883  0002005883        Gilead      NaN
# 1  9780002261982  0002261987  Spider's Web  A Novel
# 2  9780006163831  0006163831  The One Tree      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
#
#                                                                                                thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCPgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 1  http://books.google.com/books/content?id=gA5GPgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
# 2  http://books.google.com/books/content?id=OmQawwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api
#
#                                                                                                                                                                                                                                                       description  \
# 0  A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers...
# 1  A new 'Christie for Christmas' -- a full-length novel adapted from her acclaimed play by Charles Osborne Following BLACK COFFEE and THE UNEXPECTED GUEST comes the final Agatha Christie play novelisation, bringing her superb storytelling to a new legio...
# 2                                                                                                                                                   Volume Two of Stephen Donaldson's acclaimed second trilogy featuing the compelling anti-hero Thomas Covenant.
#
#    published_year  average_rating  num_pages  ratings_count
# 0          2004.0            3.85      247.0          361.0
# 1          2000.0            3.83      241.0         5164.0
# 2          1982.0            3.97      479.0          172.0

# %% [markdown]
# # Setting up the book dataset

# %% [markdown]
# First, we filter common entries from the smaller dataset with the ones in the larger one, based on the ISBN

# %%
same_title_books_df = book_list_large_df[book_list_large_df['ISBN'].isin(main_books_df['isbn10'])]

# %%
same_title_books_df.shape
# Out:
# (2447, 8)

# %% [markdown]
# Merge all of the additional columns from main_books_df and drop the duplicate column created

# %%
# Merge additional columns 
same_title_books_df = same_title_books_df.merge(main_books_df[['isbn10', 'categories', 'description']], 
                                                how='left', left_on='ISBN', right_on='isbn10')

# Drop the duplicate
same_title_books_df.drop(columns=['isbn10'], inplace=True)

# %% [markdown]
# A new merged dataset is formed

# %%
same_title_books_df.head(1)
# Out:
#          ISBN     Book-Title   Book-Author Year-Of-Publication Publisher  \
# 0  0440234743  The Testament  John Grisham                1999      Dell
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/P/0440234743.01.THUMBZZZ.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/P/0440234743.01.MZZZZZZZ.jpg
#
#                                                     Image-URL-L categories  \
# 0  http://images.amazon.com/images/P/0440234743.01.LZZZZZZZ.jpg    Fiction
#
#                                                                                                                                                                                            description
# 0  A suicidal billionaire, a burnt-out Washington litigator, and a woman who has forsaken technology to work in the wilds of Brazil are all brought together by an astounding mystery of the testament

# %% [markdown]
# Last step is to reorder the data

# %%
# Reordering columns
columns_order = ['ISBN', 'Book-Title', 'Book-Author', 'Publisher', 'Year-Of-Publication', 
                  'categories', 'description', 'Image-URL-S', 'Image-URL-M', 'Image-URL-L']

same_title_books_df = same_title_books_df[columns_order]

print("Shape: " + str(same_title_books_df.shape))
# Out:
# Shape: (2447, 10)

# %% [markdown]
# ### The base merged dataset we will be using:

# %% [markdown]
# This merge of datasets allows us to use both metadata such as categories or descriptions AND provides a link to a ratings dataset provided with the larger books dataset we used.

# %%
same_title_books_df.head(3)
# Out:
#          ISBN                                                      Book-Title  \
# 0  0440234743                                                   The Testament
# 1  0553582909                                                        Icebound
# 2  0842342702  Left Behind: A Novel of the Earth's Last Days (Left Behind #1)
#
#       Book-Author                 Publisher Year-Of-Publication categories  \
# 0    John Grisham                      Dell                1999    Fiction
# 1  Dean R. Koontz              Bantam Books                2000    Fiction
# 2      Tim Lahaye  Tyndale House Publishers                2000    Fiction
#
#                                                                                                                                                                                                                                         description  \
# 0                                               A suicidal billionaire, a burnt-out Washington litigator, and a woman who has forsaken technology to work in the wilds of Brazil are all brought together by an astounding mystery of the testament
# 1  A secret Arctic experiment turns into a frozen nightmare when a team of scientists, stranded on a drifting iceberg with a massive explosive charge, battles the elements for survival, only to discover that one of them is a murderer. Reissue.
# 2                                                                                               The first book in the author's successful "last days" series follows a 747 pilot as he tries to recover from the effects of "The Rapture." Reprint.
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/P/0440234743.01.THUMBZZZ.jpg
# 1  http://images.amazon.com/images/P/0553582909.01.THUMBZZZ.jpg
# 2  http://images.amazon.com/images/P/0842342702.01.THUMBZZZ.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/P/0440234743.01.MZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0553582909.01.MZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0842342702.01.MZZZZZZZ.jpg
#
#                                                     Image-URL-L
# 0  http://images.amazon.com/images/P/0440234743.01.LZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0553582909.01.LZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0842342702.01.LZZZZZZZ.jpg

# %%
# same_title_books_df.to_csv("./filtered_datasets/books_merge_1.csv", index=False)
# same_title_books_df = pd.read_csv("./filtered_datasets/books_merge_1.csv")

# %% [markdown]
# ---
#
# ## Error corrections in the datasets

# %% [markdown]
# #### 1. Some books in the initial, smaller dataset are exatly the same __BUT__ they are different editions

# %%
columns_with_text = same_title_books_df[same_title_books_df['Book-Title'].str.contains('The Two Towers')]
columns_with_text[["Book-Title","Image-URL-M"]].head(2)
# Out:
#                                          Book-Title  \
# 28   The Two Towers (The Lord of the Rings, Part 2)
# 430  The Two Towers (The Lord of the Rings, Part 2)
#
#                                                       Image-URL-M
# 28   http://images.amazon.com/images/P/0345339711.01.MZZZZZZZ.jpg
# 430  http://images.amazon.com/images/P/0618002235.01.MZZZZZZZ.jpg

# %% [markdown]
# Notice: they have the same name but different images

# %% [markdown]
# __Solution:__ We chose the option of removing the duplicates, as they represent the same book and tell the same story

# %%
same_title_books_df_unique = same_title_books_df.drop_duplicates(subset=['Book-Title'])
same_title_books_df_unique.to_csv("./filtered_datasets/books_merge_1.csv", index=False)
print("old :" + str(same_title_books_df.shape))
print("new :" + str(same_title_books_df_unique.shape))
# Out:
# old :(2447, 10)
# new :(2426, 10)

# %% [markdown]
# Observation: dataset took a negligable hit of only 21 entries dropped

# %% [markdown]
# #### 2. Some entries have really short or no descriptions

# %%
no_description_count = same_title_books_df['description'].isna()

print("Number of entries with no description:", no_description_count.sum())
# Out:
# Number of entries with no description: 78

# %% [markdown]
# We can see a total of 78 remaining entries have no description

# %%
same_title_books_df[no_description_count].head(5)
# Out:
#            ISBN  \
# 137  0380699176
# 212  0806509023
# 247  0345384563
# 280  0553212419
# 602  0394735307
#
#                                                                       Book-Title  \
# 137                                       100 Great Fantasy Short, Short Stories
# 212             Existentialism and Human Emotions (A Philosophical Library Book)
# 247    A History of God: The 4,000-Year Quest of Judaism, Christianity and Islam
# 280  Sherlock Holmes : The Complete Novels and Stories (Bantam Classic) Volume I
# 602                                                            The Tale of Genji
#
#                  Book-Author                           Publisher  \
# 137             Isaac Asimov  Harper Mass Market Paperbacks (Mm)
# 212         Jean-Paul Sartre                       Citadel Trade
# 247          Karen Armstrong                    Ballantine Books
# 280  Arthur Conan, Sir Doyle                              Bantam
# 602         Murasaki Shikibu                     Alfred A. Knopf
#
#     Year-Of-Publication                     categories description  \
# 137                1987                        Fiction         NaN
# 212                1984                     Philosophy         NaN
# 247                1994             God (Christianity)         NaN
# 280                1986  Detective and mystery stories         NaN
# 602                1978                            NaN         NaN
#
#                                                       Image-URL-S  \
# 137  http://images.amazon.com/images/P/0380699176.01.THUMBZZZ.jpg
# 212  http://images.amazon.com/images/P/0806509023.01.THUMBZZZ.jpg
# 247  http://images.amazon.com/images/P/0345384563.01.THUMBZZZ.jpg
# 280  http://images.amazon.com/images/P/0553212419.01.THUMBZZZ.jpg
# 602  http://images.amazon.com/images/P/0394735307.01.THUMBZZZ.jpg
#
#                                                       Image-URL-M  \
# 137  http://images.amazon.com/images/P/0380699176.01.MZZZZZZZ.jpg
# 212  http://images.amazon.com/images/P/0806509023.01.MZZZZZZZ.jpg
# 247  http://images.amazon.com/images/P/0345384563.01.MZZZZZZZ.jpg
# 280  http://images.amazon.com/images/P/0553212419.01.MZZZZZZZ.jpg
# 602  http://images.amazon.com/images/P/0394735307.01.MZZZZZZZ.jpg
#
#                                                       Image-URL-L
# 137  http://images.amazon.com/images/P/0380699176.01.LZZZZZZZ.jpg
# 212  http://images.amazon.com/images/P/0806509023.01.LZZZZZZZ.jpg
# 247  http://images.amazon.com/images/P/0345384563.01.LZZZZZZZ.jpg
# 280  http://images.amazon.com/images/P/0553212419.01.LZZZZZZZ.jpg
# 602  http://images.amazon.com/images/P/0394735307.01.LZZZZZZZ.jpg

# %% [markdown]
# Solution: Remove titles with no description

# %%
same_title_books_df = same_title_books_df.dropna(subset=['description'])

# %% [markdown]
# Some items have really short descriptions that might throw off the predictions

# %%
word_threshold = 8

short_descriptions = same_title_books_df['description'].apply(lambda x: len(str(x).split()) < word_threshold)

short_descriptions_df = same_title_books_df[short_descriptions]

pd.set_option('display.max_colwidth', 255)
print(f"Number of entries with fewer than {word_threshold} words in description:", short_descriptions.sum())
print()
short_descriptions_df[['Book-Title','description']]
# Out:
# Number of entries with fewer than 8 words in description: 37
#                                                                                 Book-Title  \
# 53                                                                    Breath, Eyes, Memory
# 126                                 Arrows of the Queen ( The Heralds of Valdemar, Book 1)
# 206                                           Triumph of the Darksword (Darksword Trilogy)
# 236                                                                           The Crack-Up
# 251                                                                                 Strata
# 317                                                                         Time And Again
# 357                       More Than Complete Hitchhiker's Guide: Complete &amp; Unabridged
# 434                                                             That Was Then, This Is Now
# 616                                                                              The Eight
# 624                                         Pride and Prejudice (Penguin Popular Classics)
# 734                                                                                 Exodus
# 829                                                           The Earth (Penguin Classics)
# 900                        The Poetry and Short Stories of Dorothy Parker (Modern Library)
# 917                                                                   Thrones, Dominations
# 983   Beyond the Hundredth Meridian: John Wesley Powell and the Second Opening of the West
# 1019                                                    Robinson Crusoe (Penguin Classics)
# 1098                              Getting Things Done: The Art of Stress-Free Productivity
# 1349                            In Search of Dracula : The History of Dracula and Vampires
# 1352                                                Good Housekeeping Illustrated Cookbook
# 1421                                       \The Silence of the Lambs\" and \"Red Dragon\""
# 1476                                              Aesop's Fables (Oxford World's Classics)
# 1556                                                        Vanity Fair (Penguin Classics)
# 1639                                                                        The Value of X
# 1717                                                                    Vinyl Cafe Diaries
# 1728                             Frankenstein: Or the Modern Prometheus (Penguin Classics)
# 1791                                                                        The Changeling
# 1803                                    De Profundis and Other Writings (Penguin Classics)
# 1874                                                                Catherine Called Birdy
# 1932                                                       Memoirs of the Second World War
# 1945                         The Soulforge (Dragonlance:  The Raistlin Chronicles, Book 1)
# 2003                                                             The Man Who Sold The Moon
# 2182               The Complete Dream Dictionary: A Practical Guide to Interpreting Dreams
# 2204                                        The Visual Display of Quantitative Information
# 2225                                                                      Bound for Oregon
# 2336                                                                 Understanding Physics
# 2346                                             The Death of Ivan Ilych and Other Stories
# 2442                                                      This Side of Brightness: A Novel
#
#                                                   description
# 53                                         Oprah's Book Club.
# 126                                             Eventyrroman.
# 206                                          Science fiction.
# 236                                       (Autobiographical).
# 251                                            Fantasy-roman.
# 317                                                  Romance.
# 357                            Five stories by Douglas Adams.
# 434                          HINTON/THAT WAS THEN THIS IS NOW
# 616                                      National bestseller.
# 624                                  First published in 1813.
# 734                                        A novel of Israel.
# 829                                        No Marketing Blurb
# 900                                            Ketubot Part I
# 917                                               Winter 1999
# 983                          Biography of John Wesley Powell.
# 1019                               DEFOE/ROBINSON CRUSOE (BC)
# 1098                                ALLEN/GETTING THINGS DONE
# 1349              Traces the history and folklore of vampires
# 1352  Over 900 dishes, plus illustrated step-by-step recipes.
# 1421                                         Kriminalromaner.
# 1476              A collection of familiar short moral tales.
# 1556                                    Edited by John Carey.
# 1639                                                  Horror.
# 1717               The further adventures of Dave and Morley.
# 1728                                Edited by Maurice Hindle.
# 1791                                   FICTION-ROMANCE/GOTHIC
# 1803                                       No Marketing Blurb
# 1874   Originally published: [New York]: Clarion Books, 1994.
# 1932                         Surveys the war and its politics
# 1945                                           Fantasy roman.
# 2003                 Comprehensive Teacher's Guide available.
# 2182                A practical guide to interpreting dreams.
# 2204             Graphical practice. Theory of data graphics.
# 2225                                    Bound For Oregon (PB)
# 2336                                 Motion, Sound, and Heat.
# 2346                                   Meaning of life novel.
# 2442                                              Winter 2003

# %% [markdown]
# So we filter out these entries

# %%
same_title_books_df = same_title_books_df[~short_descriptions]

# Display the number of remaining entries
print("Number of remaining entries:", len(same_title_books_df))
# Out:
# Number of remaining entries: 2332

# %%
same_title_books_df.to_csv("./filtered_datasets/final/final_books_content.csv", index=False)
